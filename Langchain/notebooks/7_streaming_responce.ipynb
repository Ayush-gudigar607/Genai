# %%
from  dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# %pip install langchain-openai langchain-groq
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_openai import ChatOpenAI

# %%
import os
os.environ["OPENAI_API_KEY"] = "AIzaSyDJxrZ3yMqR-87SBFKXYbNQFJdqo7E8Yo0"
  # Replace with your actual OpenAI API key

# %%
llm=ChatOpenAI(model="gemini-2.5-flash-lite",base_url="https://generativelanguage.googleapis.com/v1beta/openai/",streaming=True)

# %%
question="Who is GENAI?"

# %%
##Generators are used for streaming for that we have to use for loop
res=llm.stream(question)
for chunk in res:
    print(chunk.content,end="")
# Out:
# <generator object BaseChatModel.stream at 0x0000017768FC2B60>
# GENAI isn't a single, universally recognized individual or entity. It's **most likely a reference to Generative AI (Artificial Intelligence)**.
#
# Here's a breakdown of what that means:
#
# *   **Generative AI (GENAI):** This is a broad category of AI systems that are designed to **create new content**. This content can take many forms, including:
#     *   **Text:** Writing stories, poems, code, emails, articles, scripts, etc. (like the AI you're interacting with right now!).
#     *   **Images:** Generating realistic or artistic pictures from text descriptions.
#     *   **Audio:** Composing music, creating speech, or generating sound effects.
#     *   **Video:** Producing short video clips or animations.
#     *   **Code:** Writing software programs.
#     *   **3D Models:** Designing virtual objects.
#
# ...

# %%
# %pip install langchain-groq
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_groq import ChatGroq
llm=ChatGroq(model="openai/gpt-oss-20b",streaming=True)
query="Explain the genai?"
res=llm.stream(query)

for chunk in res:
    print(chunk.content,end="")
# Out:
# ### GenAI – Generative Artificial Intelligence
#
# **GenAI** (short for *Generative AI*) refers to a class of artificial‑intelligence systems that can **create new content**—text, images, audio, video, code, and more—by learning patterns from large datasets. Unlike traditional AI that merely classifies or predicts, generative models *produce* something that did not exist before.
#
# ---
#
# ## 1. Core Technology
#
# | Component | What It Does | Typical Models |
# |-----------|--------------|----------------|
# | **Training Data** | Huge corpora of text, images, audio, etc. | Wikipedia, books, image collections |
# | **Neural Architecture** | Deep networks that learn statistical regularities | Transformers (GPT‑4, BERT), Diffusion models, GANs, VQ‑VAE |
# | **Learning Objective** | Predict next token, reconstruct input, or minimize loss | Cross‑entropy, adversarial loss, diffusion denoising |
# ...
