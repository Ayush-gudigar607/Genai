# %% [markdown]
# QROK OPEN SOURCE MODEL FOR RUNNING LPU

# %%
# %pip install -qU langchain-groq
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import dotenv 
dotenv.load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

# %%
llm=ChatGroq(model="openai/gpt-oss-20b")

# %%
res=llm.invoke("Who is PM of India? in 2026")
print(res.content)
# Out:
# **Answer (as of the latest publicly available information)**
# - **Prime Minister of India in 2026:** **Narendra Modi** (assuming no extraordinary change such as a mid‑term resignation, a no‑confidence vote, or a special election).
#
# **Why this answer?**
# - India’s constitution mandates general elections every five years. The last election was held in 2024, so the next scheduled election will be in 2029.
# - Narendra Modi, leader of the Bharatiya Janata Party (BJP), has been serving as Prime Minister since May 2014 and was re‑elected in 2019.
# - Unless a major political event (e.g., a vote of no confidence, resignation, or a special election) occurs, the incumbent Prime Minister is expected to remain in office until the next general election.
#
# **What to keep in mind**
# - The above is based on the status quo as of 2024. Future developments (political shifts, legal challenges, etc.) could change the leadership before 2029.
# ...
